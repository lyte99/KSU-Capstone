# %%
# import python packages
import requests
from lxml import html
import csv
import pandas as pd
import nltk
from nltk import FreqDist, word_tokenize

# %matplotlib inline
import nltk
import matplotlib.pyplot as plt
import csv
import pandas as pd
import sklearn
import numpy as np
from collections import Counter
from nltk.corpus import stopwords

# feature engineering (words to vectors)
from sklearn.feature_extraction.text import TfidfVectorizer

# classification algorithms (or classifiers)
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC

# build a pipeline
from sklearn.pipeline import Pipeline

# model evaluation, validation
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split, GridSearchCV 
from sklearn import metrics
from sklearn.metrics import roc_curve, auc

#plotting
import scikitplot as skplt

# %%
# load data
Data_Breaches = []

openfile = open("Datasets/Cleaned/Privacy_Rights_Cleaned.csv", "rb")
r = csv.reader(openfile)

for i in r:
    Data_Breaches.append(i)
openfile.close()

# %%
#convert to pandas    
Data_Breaches_DF = pd.DataFrame(Data_Breaches)

#set column names
Data_Breaches_DF.columns = ['Company','Year','Month','Day of Month','City','State', 'Country','Data_Public', 'Breach_Type','Org_Type','Total_Records','Description']
           
#set total_records to float datatype
Data_Breaches_DF['Total_Records'] = Data_Breaches_DF.Total_Records.astype(float)
    
#check data
Data_Breaches_DF.head(5)
# Out:
#                                            Company  Year Month Day of Month  \
# 0                                   ﻿1 Chat Avenue  2012     2           13
# 1  101 Family Medical Group Privacy Manager Breach  2014     1            8
# 2                                     101Domaincom  2011    11           27
# 3                                      1800Flowers  2016     3            8
# 4                                 1st Mariner Bank  2018     2            5
#
#           City       State Country Data_Public    Breach_Type  \
# 0                   Kansas     USA   2/13/2012        Hacking
# 1               California     USA    1/8/2014  Physical Loss
# 2     Carlsbad  California     USA  11/27/2011        Hacking
# 3  Carle Place    New York     USA    3/8/2016        Hacking
# 4    Baltimore    Maryland     USA    2/5/2018        Hacking
#
#                Org_Type  Total_Records  \
# 0        Business Other           39.0
# 1      Medical Provider         2500.0
# 2        Business Other        10000.0
# 3        Business Other            0.0
# 4  Finance Or Insurance         1500.0
#
#                                          Description
# 0  A hacker or hackers accessed and posted online...
# 1  A laptop computer owned by Phressia, Inc., a b...
# 2  A phishing attack exposed the personal informa...
# 3  1-800-Flowers customer service received report...
# 4  1st Mariner Bank experienced a phishing attack...

# %%
#populate  data
description_data = []
description_labels = []
description_all = []


for index, row in Data_Breaches_DFData_Breaches_DF.loc[Data_Breaches_DF['Breach_Type'] == 'Hacking'].iterrows():
    article_all.append(row)
    article_data.append(row['Article_Name'])
    article_labels.append("HR")
    
for index, row in other_articles.iterrows():
    article_all.append(row)
    article_data.append(row['Article_Name'])
    article_labels.append("NOT_HR")
